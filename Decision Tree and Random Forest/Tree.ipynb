# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sb

# %%
df = pd.read_csv('kyphosis.csv') #This is a spinal cord dataset where you need to predict whether the kyphosis was present after the surgery or not

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
sb.pairplot(df, hue='Kyphosis', palette='Set1') #To see the varriety of the data distribution among themselves

# %% [markdown]
# **Let's train and Evaluate the Model**

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis', axis=1) #Features of the dataset
y = df['Kyphosis'] #Target of the dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier #Importing the DTree module from sklearn

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, pred))
print("\n")
print(confusion_matrix(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.72      0.91      0.81        23
#      present       0.50      0.20      0.29        10
#
#     accuracy                           0.70        33
#    macro avg       0.61      0.56      0.55        33
# weighted avg       0.66      0.70      0.65        33
#
#
#
# [[21  2]
#  [ 8  2]]

# %% [raw]
# So after training and predicting the single decision tree has accuracy about 73%, so we need use the Random Forst to improve the performance of the Single decision tree

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=300)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
pred_rfc = rfc.predict(X_test)

# %%
print(classification_report(y_test, pred_rfc))
print("\n")
print(confusion_matrix(y_test, pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.74      1.00      0.85        23
#      present       1.00      0.20      0.33        10
#
#     accuracy                           0.76        33
#    macro avg       0.87      0.60      0.59        33
# weighted avg       0.82      0.76      0.69        33
#
#
#
# [[23  0]
#  [ 8  2]]

# %% [markdown]
# **After training the model using Random Forest, the acccuracy was increased to 3% i.e 76%**
